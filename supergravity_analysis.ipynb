# %% [markdown]
# # Analysis of Supergravity Potential in 2511.02981
#
# The notebook below provides code supporting the manuscript.
#
# The gradient descent to sample the moduli space is omitted because it is very computationally intensive.
# Instead, we provide a sample of results in an accompanying `Points_5d.npy`

# %%
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px

from sklearn.cluster import HDBSCAN

from ASMC import SparsePolynomialSampler, utils
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Config
colors = [[0.1,0.3,0.45],[0.65,0.35,0],[0.5,0.0,0.13],[0.08,0.48,0.31],[0.75,0.36,0.51],[0.99,0.86,0.18],[1.0,0.84,0.64]]

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Helvetica"
})

plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['font.family'] = 'cmu'
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['axes.labelsize'] = 13

# %%
# Load points obtained from gradient descent
x_5d = np.load('Points_5d.npy')

# %% [markdown]
# ## Analysis of Gradient Descent

# %%
# Inspection of conformal manifold
utils.triangular_plot(x_5d,names=[r'$x_1$',r'$x_2$',r'$x_4$',r'$\tilde{x}_8$',r'$x_{10}$'])

# %% [markdown]
# ## Local Analysis

# %%
# Computation of local dimensions using KD-Tree
loc_dim_diff_nneig = []
all_n_neig = [5,10,20,50]

for i in all_n_neig:
    print(i)
    loc_dim = utils.local_dim_n_points(x_5d,
                             verbose=1,
                             n_neig=i,
                             n_jobs=4)
    loc_dim_diff_nneig.append(loc_dim)
# Out:
# 5
# Searching for neighbors using KD-Tree...
# Computing the local dimensions...
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Computation finished!
# 10
# Searching for neighbors using KD-Tree...
# Computing the local dimensions...
# Computation finished!
# 20
# Searching for neighbors using KD-Tree...
# Computing the local dimensions...
# Computation finished!
# 50
# Searching for neighbors using KD-Tree...
# Computing the local dimensions...
# Computation finished!

# %%
all_dim = []
for i in range(len(all_n_neig)):
    all_dim.append([np.sum(np.array(loc_dim_diff_nneig[i])[:,0]==k)/len(x_5d) for k in range(6)])


# plt.figure(figsize=(10, 10))
# for i in range(len(all_n_neig)):
#     plt.plot(range(1,6),np.array(all_dim[i]),label=str(all_n_neig[i]))
#     plt.scatter(range(1,6), np.array(all_dim[i]), s=100)
# plt.xlabel("Dimension")
# plt.ylabel("Number of points",labelpad=15)
# plt.legend()
# plt.grid()
# plt.show()

plt.figure()
for i in range(1,len(all_n_neig)):
    plt.plot(range(6),np.array(all_dim[i]),label=str(all_n_neig[i]),color=colors[i-1])
    plt.scatter(range(6), np.array(all_dim[i]), s=20, color=colors[i-1])
plt.xlabel(r"Dimension")
plt.ylabel(r"Proportion of points", labelpad=15)
leg = plt.legend(title = '$k$--nearest\nneighbours')
leg.get_title().set_multialignment('center')
plt.grid(linewidth=0.15)
plt.show()

# %% [markdown]
# ## Clustering

# %%
all_local_dim_5d = np.array(loc_dim_diff_nneig)[2][:,0] 
x_5d_deco = x_5d[np.array(all_local_dim_5d)==3]

# %%
clusterer = HDBSCAN(min_cluster_size=10, copy=False)
labels = clusterer.fit_predict(x_5d_deco)

# %%
for lab_idx in range(np.max(labels)+2):
    print(x_5d_deco[labels==lab_idx-1].shape)
# Out:
# (1583, 5)
# (7525, 5)
# (17, 5)

# %%
fig, axes = plt.subplots(5, 2, subplot_kw={'projection': '3d'}, figsize=(10, 25))

axes[0,0].scatter(x_5d_deco[:,0],x_5d_deco[:,1],x_5d_deco[:,2],c=labels, cmap="viridis",s=0.2)
axes[0,1].scatter(x_5d_deco[:,0],x_5d_deco[:,1],x_5d_deco[:,3],c=labels, cmap="viridis",s=0.2)
axes[1,0].scatter(x_5d_deco[:,0],x_5d_deco[:,1],x_5d_deco[:,4],c=labels, cmap="viridis",s=0.2)
axes[1,1].scatter(x_5d_deco[:,0],x_5d_deco[:,2],x_5d_deco[:,3],c=labels, cmap="viridis",s=0.2)
axes[2,0].scatter(x_5d_deco[:,0],x_5d_deco[:,2],x_5d_deco[:,4],c=labels, cmap="viridis",s=0.2)
axes[2,1].scatter(x_5d_deco[:,0],x_5d_deco[:,3],x_5d_deco[:,4],c=labels, cmap="viridis",s=0.2)
axes[3,0].scatter(x_5d_deco[:,1],x_5d_deco[:,2],x_5d_deco[:,3],c=labels, cmap="viridis",s=0.2)
axes[3,1].scatter(x_5d_deco[:,1],x_5d_deco[:,2],x_5d_deco[:,4],c=labels, cmap="viridis",s=0.2)
axes[4,0].scatter(x_5d_deco[:,1],x_5d_deco[:,2],x_5d_deco[:,3],c=labels, cmap="viridis",s=0.2)
axes[4,1].scatter(x_5d_deco[:,2],x_5d_deco[:,3],x_5d_deco[:,4],c=labels, cmap="viridis",s=0.2)
plt.show()

# %%
# Scatter plot
fig = px.scatter_3d(x=x_5d_deco[:,2], y=x_5d_deco[:,3], z=x_5d_deco[:,4], 
                    color=labels, labels={'x':'x_4', 'y':'x_8', 'z':'x_10'})
fig.update_layout(width=1000, height=800)
fig.update_traces(marker=dict(size=2)) 

fig.update_layout(scene=dict(xaxis_title='x_5', yaxis_title='x_8', zaxis_title='x_9'))
fig.show()

# %% [markdown]
# Homogenisation through de-sampling

# %%
from itertools import product

lim = [-3,3]
step = 0.25
temp_steps = np.arange(lim[0],lim[-1]+step,step)
box1d = np.array([[temp_steps[ii], temp_steps[ii+1]] for ii in range(len(temp_steps)-1)])
box5d = np.array([np.array(ele) for ele in product(box1d, repeat = x_5d_deco.shape[1])])

def test_inclusion_1d(arr1d, interval):
    return (interval[0] <= arr1d) & (arr1d< interval[1])

count = np.zeros(box5d.shape[0])
threshold = 10
x5d_desampled = np.array([]).reshape((0,5))

for (pos,box) in enumerate(box5d):
    inclusion_mask = np.ones(x_5d_deco.shape[0],dtype=bool)

    for ii in range(x_5d_deco.shape[1]):
        inclusion_mask = np.logical_and(inclusion_mask,test_inclusion_1d(x_5d_deco[:,ii],box[ii]))
    count[pos] = inclusion_mask.sum()

    # We apply a threshold on the number of points allowed in a box
    selected = x_5d_deco[inclusion_mask]
    if count[pos] <= threshold:
        x5d_desampled = np.concatenate((x5d_desampled,selected))
    else:
        to_be_chosen = np.random.choice(range(selected.shape[0]), threshold, replace=False)
        x5d_desampled = np.concatenate((x5d_desampled,selected[to_be_chosen]))

# %% [markdown]
# ## ASMC Fitting

# %%
my_data_raw = np.load("./Points_5d.npy")

my_data_x = np.array([my_data_raw[:,0],
                     my_data_raw[:,1],
                     my_data_raw[:,2],
                     np.exp(my_data_raw[:,3]),
                     my_data_raw[:,4]]).T

# %%
sampler = SparsePolynomialSampler(
    data_x=my_data_x,
    max_degree=5,
    num_vars=5,
    max_num_monomials=5,
    prob_add= lambda i,n_iter: 0., 
    prob_remove= lambda i,n_iter: 0., 
    prob_modify= lambda i,n_iter: 0.5, 
    prob_multiply= lambda i,n_iter: 0.25, 
    prob_divide= lambda i,n_iter: 0.25, 
    regularisation_factor=1e3,
    sigma_proposal = lambda i,n_iter: 0.1,
    )
# Out:
# Pre-compute multiply/divide transitions...
#   Average of multiply transitions: 2.50
#   Average of divide transitions: 2.50
# Number of possible terms in the polynomial: 252

# %%
all_out = sampler.run_annealing_is(
    n_iter=1000,       
    n_particles=1000,  
    verbose=True,
    adaptative_temp=True,
    degree_bias=0.,
    sparsity_factor=0.,
    adaptation_strength=lambda i,n_iter : 0.05,
    target_acc_rate = lambda x,y : 0.8 - 0.5 * x/y,
    beta_schedule=lambda i,n_iter: 1e-10
)
# Out:
# Iteration 1/1000, 	Beta: 1e-10, 	Acceptance rate: 1.00, 	ESS: 1000.00/1000, 	Best loss: 9645.475798,	Elapsed time: 0.96s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3669*x2*x4 + 0.3709*x1*x2^2 + 0.1030*x1*x2*x3*x5^2 + 0.3163*x1^2*x2*x3*x5 + 0.1920*x1^2*x2^2*x5
# Iteration 2/1000, 	Beta: 1.1e-10, 	Acceptance rate: 1.00, 	ESS: 999.99/1000, 	Best loss: 9426.911905,	Elapsed time: 1.22s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3375*x2*x4 + 0.3709*x1*x2^2 + 0.1030*x1*x2*x3*x5^2 + 0.3163*x1^2*x2*x3*x5 + 0.1920*x1^2*x2^2*x5
# Iteration 3/1000, 	Beta: 1.1e-10, 	Acceptance rate: 1.00, 	ESS: 999.98/1000, 	Best loss: 9264.402243,	Elapsed time: 1.45s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3375*x2*x4 + 0.3709*x1*x2^2 + 0.3163*x1^2*x3*x5 + 0.1030*x1*x2*x3*x5^2 + 0.1920*x1^2*x2^2*x5
# Iteration 4/1000, 	Beta: 1.2e-10, 	Acceptance rate: 1.00, 	ESS: 999.94/1000, 	Best loss: 9089.792331,	Elapsed time: 1.69s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3375*x2*x4 + 0.3709*x1*x2^2 + 0.3163*x1^2*x3*x5 + 0.1030*x1*x2*x3*x5^2 + 0.1468*x1^2*x2^2*x5
# Iteration 5/1000, 	Beta: 1.2e-10, 	Acceptance rate: 1.00, 	ESS: 999.91/1000, 	Best loss: 8795.514362,	Elapsed time: 1.91s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2119*x2*x4 + 0.3709*x1*x2^2 + 0.3163*x1^2*x3*x5 + 0.1030*x1*x2*x3*x5^2 + 0.1468*x1^2*x2^2*x5
# Iteration 6/1000, 	Beta: 1.3e-10, 	Acceptance rate: 1.00, 	ESS: 999.73/1000, 	Best loss: 8795.514362,	Elapsed time: 2.15s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2119*x2*x4 + 0.3709*x1*x2^2 + 0.3163*x1^2*x3*x5 + 0.1604*x1*x2*x3*x5^2 + 0.1468*x1^2*x2^2*x5
# Iteration 7/1000, 	Beta: 1.3e-10, 	Acceptance rate: 1.00, 	ESS: 999.68/1000, 	Best loss: 8795.514362,	Elapsed time: 2.38s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2119*x2*x4^2 + 0.3709*x1*x2^2 + 0.3163*x1^2*x3*x5 + 0.1604*x1*x2*x3*x5^2 + 0.1468*x1^2*x2^2*x5
# Iteration 8/1000, 	Beta: 1.4e-10, 	Acceptance rate: 1.00, 	ESS: 999.37/1000, 	Best loss: 8795.514362,	Elapsed time: 2.61s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.1448*x2*x4^2 + 0.3709*x1*x2^2 + 0.3163*x1^2*x3*x5 + 0.1604*x1*x2*x3*x5^2 + 0.1468*x1^2*x2^2*x5
# Iteration 9/1000, 	Beta: 1.5e-10, 	Acceptance rate: 1.00, 	ESS: 999.23/1000, 	Best loss: 8795.514362,	Elapsed time: 2.81s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.1448*x2*x4^2 + 0.3709*x1*x2^2 + 0.1604*x1*x3*x5^2 + 0.3163*x1^2*x3*x5 + 0.1468*x1^2*x2^2*x5
# Iteration 10/1000, 	Beta: 1.6e-10, 	Acceptance rate: 1.00, 	ESS: 999.17/1000, 	Best loss: 8795.514362,	Elapsed time: 3.08s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.1448*x2*x4^2 + 0.4174*x1*x2^2 + 0.1604*x1*x3*x5^2 + 0.3163*x1^2*x3*x5 + 0.1468*x1^2*x2^2*x5
# Iteration 11/1000, 	Beta: 1.6e-10, 	Acceptance rate: 1.00, 	ESS: 999.06/1000, 	Best loss: 8795.514362,	Elapsed time: 3.30s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0144*x3 + 0.6372*x2 - 1.3332*x1 - 0.0743*x3*x5^2 - 0.2376*x1*x2*x5
# Iteration 12/1000, 	Beta: 1.7e-10, 	Acceptance rate: 1.00, 	ESS: 998.97/1000, 	Best loss: 8795.514362,	Elapsed time: 3.54s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.6372*x2 - 1.3332*x1 - 0.0144*x3^2 - 0.0743*x3*x5^2 - 0.2376*x1*x2*x5
# Iteration 13/1000, 	Beta: 1.8e-10, 	Acceptance rate: 1.00, 	ESS: 998.91/1000, 	Best loss: 8795.514362,	Elapsed time: 3.74s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.6372*x2 - 1.3332*x1 - 0.0144*x3^2 - 0.0743*x3*x5^2 - 0.2771*x1*x2*x5
# Iteration 14/1000, 	Beta: 1.9e-10, 	Acceptance rate: 1.00, 	ESS: 998.79/1000, 	Best loss: 8795.514362,	Elapsed time: 4.00s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.0912*x2*x4^2 + 0.1604*x1*x3*x5^2 + 0.4174*x1*x2^2*x3 + 0.4222*x1^2*x3*x5 + 0.1664*x1^2*x2^2*x5
# Iteration 15/1000, 	Beta: 2e-10, 	Acceptance rate: 1.00, 	ESS: 998.71/1000, 	Best loss: 8795.514362,	Elapsed time: 4.21s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.0912*x2*x4^2 + 0.1604*x1*x3*x5^2 + 0.3346*x1*x2^2*x3 + 0.4222*x1^2*x3*x5 + 0.1664*x1^2*x2^2*x5
# Iteration 16/1000, 	Beta: 2.1e-10, 	Acceptance rate: 1.00, 	ESS: 998.38/1000, 	Best loss: 8795.514362,	Elapsed time: 4.43s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.0912*x2*x4^2 + 0.1604*x1*x3*x5^2 + 0.3346*x1*x2^2*x3 + 0.5665*x1^2*x3*x5 + 0.1664*x1^2*x2^2*x5
# Iteration 17/1000, 	Beta: 2.2e-10, 	Acceptance rate: 1.00, 	ESS: 998.29/1000, 	Best loss: 8795.514362,	Elapsed time: 4.63s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4933*x1*x4 + 0.1991*x1^2*x2 - 1.6767*x2*x4*x5^3 + 1.0752*x2*x3*x4*x5^2 + 0.4420*x1*x2^2*x5^2
# Iteration 18/1000, 	Beta: 2.3e-10, 	Acceptance rate: 1.00, 	ESS: 998.15/1000, 	Best loss: 8795.514362,	Elapsed time: 4.88s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4933*x1*x4 + 0.1991*x1^2*x2 - 1.6767*x2*x4*x5^3 + 1.0451*x2*x3*x4*x5^2 + 0.4420*x1*x2^2*x5^2
# Iteration 19/1000, 	Beta: 2.4e-10, 	Acceptance rate: 1.00, 	ESS: 998.10/1000, 	Best loss: 8795.514362,	Elapsed time: 5.14s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4933*x1 + 0.1991*x1^2*x2 - 1.6767*x2*x4*x5^3 + 1.0451*x2*x3*x4*x5^2 + 0.4420*x1*x2^2*x5^2
# Iteration 20/1000, 	Beta: 2.5e-10, 	Acceptance rate: 1.00, 	ESS: 998.03/1000, 	Best loss: 8795.514362,	Elapsed time: 5.37s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4238*x1 + 0.1991*x1^2*x2 - 1.6767*x2*x4*x5^3 + 1.0451*x2*x3*x4*x5^2 + 0.4420*x1*x2^2*x5^2
# Iteration 21/1000, 	Beta: 2.7e-10, 	Acceptance rate: 1.00, 	ESS: 997.83/1000, 	Best loss: 8795.514362,	Elapsed time: 5.60s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4238*x1 + 0.1991*x1^2*x2 - 1.7448*x2*x4*x5^3 + 1.0451*x2*x3*x4*x5^2 + 0.4420*x1*x2^2*x5^2
# Iteration 22/1000, 	Beta: 2.8e-10, 	Acceptance rate: 1.00, 	ESS: 997.65/1000, 	Best loss: 8795.514362,	Elapsed time: 5.85s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3551*x1 + 0.1991*x1^2*x2 - 1.7448*x2*x4*x5^3 + 1.0451*x2*x3*x4*x5^2 + 0.4420*x1*x2^2*x5^2
# Iteration 23/1000, 	Beta: 2.9e-10, 	Acceptance rate: 1.00, 	ESS: 998.21/1000, 	Best loss: 8795.514362,	Elapsed time: 6.11s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.0790*x1*x2 - 0.9620*x1*x2^2*x5 + 0.0917*x1^2*x3*x4 - 0.3210*x2^2*x4^2*x5 + 0.3269*x2^3*x4*x5
# Iteration 24/1000, 	Beta: 3.1e-10, 	Acceptance rate: 1.00, 	ESS: 998.25/1000, 	Best loss: 8795.514362,	Elapsed time: 6.30s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3551*x1 - 1.7448*x2*x4*x5 + 0.1991*x1^2*x2 + 1.0451*x2*x3*x4*x5^2 + 0.4420*x1*x2^2*x5^2
# Iteration 25/1000, 	Beta: 3.2e-10, 	Acceptance rate: 1.00, 	ESS: 998.19/1000, 	Best loss: 8795.514362,	Elapsed time: 6.51s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3551*x1 - 1.7448*x2*x4*x5 + 0.1991*x1^2*x2 + 1.0451*x2*x3*x4*x5^2 + 0.4362*x1*x2^2*x5^2
# Iteration 26/1000, 	Beta: 3.4e-10, 	Acceptance rate: 1.00, 	ESS: 998.11/1000, 	Best loss: 8795.514362,	Elapsed time: 6.76s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3551*x1 - 1.7690*x2*x4*x5 + 0.1991*x1^2*x2 + 1.0451*x2*x3*x4*x5^2 + 0.4362*x1*x2^2*x5^2
# Iteration 27/1000, 	Beta: 3.6e-10, 	Acceptance rate: 1.00, 	ESS: 997.92/1000, 	Best loss: 8795.514362,	Elapsed time: 7.01s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2989*x1 - 1.2229*x2*x3 - 0.6249*x2^2*x4*x5 - 0.0843*x1*x2*x3*x5 + 0.0076*x1*x4^2*x5^2
# Iteration 28/1000, 	Beta: 3.7e-10, 	Acceptance rate: 1.00, 	ESS: 997.76/1000, 	Best loss: 8795.514362,	Elapsed time: 7.24s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3551*x1 - 1.7690*x2*x4*x5 + 0.4362*x2^2*x5 + 0.1991*x1^2*x2 + 1.0451*x2*x3*x4*x5^2
# Iteration 29/1000, 	Beta: 3.9e-10, 	Acceptance rate: 1.00, 	ESS: 997.70/1000, 	Best loss: 8795.514362,	Elapsed time: 7.47s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3551*x1 - 1.7690*x2*x4*x5 + 0.4362*x2^2*x5 + 0.1991*x1^2*x2*x4 + 1.0451*x2*x3*x4*x5^2
# Iteration 30/1000, 	Beta: 4.1e-10, 	Acceptance rate: 1.00, 	ESS: 997.65/1000, 	Best loss: 8795.514362,	Elapsed time: 7.71s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.9974*x5 - 0.0503*x2 - 1.4156*x3^2*x5 + 1.1805*x4*x5^3 + 0.0341*x1^2*x3^2*x5
# Iteration 31/1000, 	Beta: 4.3e-10, 	Acceptance rate: 1.00, 	ESS: 997.57/1000, 	Best loss: 8795.514362,	Elapsed time: 7.95s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.9974*x5 - 0.0503*x2 - 1.4156*x3^2*x5 + 1.1508*x4*x5^3 + 0.0341*x1^2*x3^2*x5
# Iteration 32/1000, 	Beta: 4.5e-10, 	Acceptance rate: 1.00, 	ESS: 997.56/1000, 	Best loss: 8795.514362,	Elapsed time: 8.15s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.0665*x1 - 0.1915*x2*x3 - 0.1075*x1*x2*x5 + 0.0892*x1*x3^4
# Iteration 33/1000, 	Beta: 4.8e-10, 	Acceptance rate: 1.00, 	ESS: 997.41/1000, 	Best loss: 8795.514362,	Elapsed time: 8.39s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.0972*x1 - 0.1915*x2*x3 - 0.1075*x1*x2*x5 + 0.0892*x1*x3^4
# Iteration 34/1000, 	Beta: 5e-10, 	Acceptance rate: 1.00, 	ESS: 997.29/1000, 	Best loss: 7122.839907,	Elapsed time: 8.56s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2231*x5 + 0.7515*x3 + 0.1081*x5^3 - 0.4978*x2^2*x3*x4 + 0.1310*x1^2*x2*x5^2
# Iteration 35/1000, 	Beta: 5.3e-10, 	Acceptance rate: 1.00, 	ESS: 997.17/1000, 	Best loss: 7122.839907,	Elapsed time: 8.82s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2231*x5 + 0.7515*x3 + 0.1081*x5^3 - 0.4978*x2^2*x3*x4 + 0.1560*x1^2*x2*x5^2
# Iteration 36/1000, 	Beta: 5.5e-10, 	Acceptance rate: 1.00, 	ESS: 997.06/1000, 	Best loss: 7122.839907,	Elapsed time: 9.04s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2231 + 0.7515*x3 + 0.1081*x5^3 - 0.4978*x2^2*x3*x4 + 0.1560*x1^2*x2*x5^2
# Iteration 37/1000, 	Beta: 5.8e-10, 	Acceptance rate: 1.00, 	ESS: 996.77/1000, 	Best loss: 6917.435816,	Elapsed time: 9.28s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2231 + 0.7515*x3 + 0.1081*x5^3 - 0.4978*x2^2*x3*x4 + 0.0491*x1^2*x2*x5^2
# Iteration 38/1000, 	Beta: 6.1e-10, 	Acceptance rate: 1.00, 	ESS: 996.57/1000, 	Best loss: 6807.993365,	Elapsed time: 9.52s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2231*x5 + 0.7515*x3 + 0.1081*x5^3 - 0.4978*x2^2*x3*x4 + 0.0491*x1^2*x2*x5^2
# Iteration 39/1000, 	Beta: 6.4e-10, 	Acceptance rate: 1.00, 	ESS: 997.28/1000, 	Best loss: 6807.993365,	Elapsed time: 9.75s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3984 + 0.0847*x1 - 0.1879*x1*x2*x5 + 0.0892*x1*x3^4
# Iteration 40/1000, 	Beta: 6.7e-10, 	Acceptance rate: 1.00, 	ESS: 997.21/1000, 	Best loss: 6807.993365,	Elapsed time: 9.97s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2176*x5 + 0.7515*x2*x3 + 0.1081*x5^3 - 0.4978*x2^2*x3*x4 + 0.0491*x1^2*x2*x5^2
# Iteration 41/1000, 	Beta: 7e-10, 	Acceptance rate: 1.00, 	ESS: 997.10/1000, 	Best loss: 6807.993365,	Elapsed time: 10.20s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.1880*x1*x2 + 0.3308*x1^2 + 0.7048*x1*x5^2 + 0.0823*x1^2*x2*x5 + 0.1765*x1*x3*x4*x5^2
# Iteration 42/1000, 	Beta: 7.4e-10, 	Acceptance rate: 1.00, 	ESS: 997.00/1000, 	Best loss: 6807.993365,	Elapsed time: 10.44s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3984 - 0.0755*x1 - 0.1879*x1*x2*x5 + 0.1446*x1*x3^3
# Iteration 43/1000, 	Beta: 7.8e-10, 	Acceptance rate: 1.00, 	ESS: 996.97/1000, 	Best loss: 6807.993365,	Elapsed time: 10.68s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3984 - 0.0755*x1 + 0.1446*x1*x3^3 - 0.1879*x1*x2^2*x5
# Iteration 44/1000, 	Beta: 8.1e-10, 	Acceptance rate: 1.00, 	ESS: 996.79/1000, 	Best loss: 6807.993365,	Elapsed time: 10.89s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3984 - 0.0755*x1 - 0.0539*x1*x3^3 - 0.1879*x1*x2^2*x5
# Iteration 45/1000, 	Beta: 8.6e-10, 	Acceptance rate: 1.00, 	ESS: 996.74/1000, 	Best loss: 6807.993365,	Elapsed time: 11.08s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3984 - 0.0755*x1 - 0.0539*x3^3 - 0.1879*x1*x2^2*x5
# Iteration 46/1000, 	Beta: 9e-10, 	Acceptance rate: 1.00, 	ESS: 996.65/1000, 	Best loss: 6586.660565,	Elapsed time: 11.31s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4479 - 0.0755*x1 - 0.0539*x3^3 - 0.1879*x1*x2^2*x5
# Iteration 47/1000, 	Beta: 9.4e-10, 	Acceptance rate: 1.00, 	ESS: 996.54/1000, 	Best loss: 6516.096937,	Elapsed time: 11.58s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4479 - 0.0755*x1 + 0.0274*x3^3 - 0.1879*x1*x2^2*x5
# Iteration 48/1000, 	Beta: 9.9e-10, 	Acceptance rate: 1.00, 	ESS: 996.39/1000, 	Best loss: 6501.152421,	Elapsed time: 11.80s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4479 - 0.0755*x1 + 0.0274*x3^3*x5 - 0.1879*x1*x2^2*x5
# Iteration 49/1000, 	Beta: 1e-09, 	Acceptance rate: 1.00, 	ESS: 996.44/1000, 	Best loss: 6501.152421,	Elapsed time: 12.04s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4479 - 0.0755*x1 + 0.0274*x3^3 - 0.1879*x1*x2^2*x5
# Iteration 50/1000, 	Beta: 1.1e-09, 	Acceptance rate: 1.00, 	ESS: 996.26/1000, 	Best loss: 6310.493474,	Elapsed time: 12.24s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4998 - 0.0755*x1 + 0.0274*x3^3 - 0.1879*x1*x2^2*x5
# Iteration 51/1000, 	Beta: 1.1e-09, 	Acceptance rate: 1.00, 	ESS: 996.16/1000, 	Best loss: 6205.926355,	Elapsed time: 12.44s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4998 - 0.1685*x1 + 0.0274*x3^3 - 0.1879*x1*x2^2*x5
# Iteration 52/1000, 	Beta: 1.2e-09, 	Acceptance rate: 1.00, 	ESS: 996.09/1000, 	Best loss: 6117.409829,	Elapsed time: 12.68s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4998 - 0.2468*x1 + 0.0274*x3^3 - 0.1879*x1*x2^2*x5
# Iteration 53/1000, 	Beta: 1.3e-09, 	Acceptance rate: 1.00, 	ESS: 996.10/1000, 	Best loss: 6116.201751,	Elapsed time: 12.93s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4998 - 0.2468*x1 + 0.0274*x3^3 - 0.1753*x1*x2^2*x5
# Iteration 54/1000, 	Beta: 1.3e-09, 	Acceptance rate: 1.00, 	ESS: 996.03/1000, 	Best loss: 6116.201751,	Elapsed time: 13.17s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4998 - 0.2468*x1 - 0.1151*x3^3 - 0.1753*x1*x2^2*x5
# Iteration 55/1000, 	Beta: 1.4e-09, 	Acceptance rate: 1.00, 	ESS: 995.88/1000, 	Best loss: 6116.201751,	Elapsed time: 13.38s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4998 - 0.2468*x1 - 0.1151*x3^2 - 0.1753*x1*x2^2*x5
# Iteration 56/1000, 	Beta: 1.5e-09, 	Acceptance rate: 1.00, 	ESS: 996.71/1000, 	Best loss: 6116.201751,	Elapsed time: 13.63s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4998 - 0.2468*x1 - 0.1151*x3^2 - 0.1061*x1*x2^2*x5
# Iteration 57/1000, 	Beta: 1.5e-09, 	Acceptance rate: 1.00, 	ESS: 996.61/1000, 	Best loss: 6116.201751,	Elapsed time: 13.89s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828 - 0.2468*x1 - 0.1151*x3^2 - 0.1061*x1*x2^2*x5
# Iteration 58/1000, 	Beta: 1.6e-09, 	Acceptance rate: 1.00, 	ESS: 996.48/1000, 	Best loss: 6116.201751,	Elapsed time: 14.10s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828 - 0.2468*x1 - 0.1151*x3^2 - 0.2289*x1*x2^2*x5
# Iteration 59/1000, 	Beta: 1.7e-09, 	Acceptance rate: 1.00, 	ESS: 995.66/1000, 	Best loss: 6116.201751,	Elapsed time: 14.36s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828 - 0.1151*x3^2 - 0.2468*x1*x5 - 0.2289*x1*x2^2*x5
# Iteration 60/1000, 	Beta: 1.8e-09, 	Acceptance rate: 1.00, 	ESS: 994.70/1000, 	Best loss: 5900.820996,	Elapsed time: 14.58s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828*x1 - 0.1151*x3^2 - 0.2468*x1*x5 - 0.2289*x1*x2^2*x5
# Iteration 61/1000, 	Beta: 1.9e-09, 	Acceptance rate: 1.00, 	ESS: 995.06/1000, 	Best loss: 5825.088887,	Elapsed time: 14.80s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828*x1 - 0.1151*x3^2 - 0.2468*x1*x5 - 0.1996*x1*x2^2*x5
# Iteration 62/1000, 	Beta: 2e-09, 	Acceptance rate: 1.00, 	ESS: 994.98/1000, 	Best loss: 5825.088887,	Elapsed time: 15.04s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828*x1 - 0.1151*x3^2 - 0.2468*x1*x5 - 0.2393*x1*x2^2*x5
# Iteration 63/1000, 	Beta: 2.1e-09, 	Acceptance rate: 1.00, 	ESS: 994.69/1000, 	Best loss: 5825.088887,	Elapsed time: 15.30s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828*x1 - 0.1151*x3^2 - 0.2468*x1*x5 - 0.2071*x1*x2^2*x5
# Iteration 64/1000, 	Beta: 2.2e-09, 	Acceptance rate: 1.00, 	ESS: 994.37/1000, 	Best loss: 5825.088887,	Elapsed time: 15.56s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828*x1 - 0.1151*x3^2 - 0.2468*x1*x5^2 - 0.2071*x1*x2^2*x5
# Iteration 65/1000, 	Beta: 2.3e-09, 	Acceptance rate: 1.00, 	ESS: 994.51/1000, 	Best loss: 5825.088887,	Elapsed time: 15.81s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828*x1 + 0.1778*x3^2 - 0.2468*x1*x5^2 - 0.2071*x1*x2^2*x5
# Iteration 66/1000, 	Beta: 2.4e-09, 	Acceptance rate: 1.00, 	ESS: 994.35/1000, 	Best loss: 5825.088887,	Elapsed time: 16.04s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828*x1 + 0.1778*x3^2 - 0.2468*x1*x5^2 - 0.2071*x1*x2^3*x5
# Iteration 67/1000, 	Beta: 2.5e-09, 	Acceptance rate: 1.00, 	ESS: 994.44/1000, 	Best loss: 5757.208034,	Elapsed time: 16.24s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828*x1 - 0.2468*x5^2 + 0.1778*x3^2 - 0.2071*x1*x2^3*x5
# Iteration 68/1000, 	Beta: 2.6e-09, 	Acceptance rate: 1.00, 	ESS: 994.09/1000, 	Best loss: 5757.208034,	Elapsed time: 16.53s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4828*x1 + 0.1778*x3^2 - 0.2468*x5^3 - 0.2071*x1*x2^3*x5
# Iteration 69/1000, 	Beta: 2.8e-09, 	Acceptance rate: 1.00, 	ESS: 994.19/1000, 	Best loss: 5757.208034,	Elapsed time: 16.76s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.1778*x3 - 0.4828*x1 - 0.2468*x5^3 - 0.2071*x1*x2^3*x5
# Iteration 70/1000, 	Beta: 2.9e-09, 	Acceptance rate: 1.00, 	ESS: 994.18/1000, 	Best loss: 5757.208034,	Elapsed time: 16.97s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.1778*x3 - 0.4828*x1 - 0.2468*x5^3 - 0.2071*x1*x2^3
# Iteration 71/1000, 	Beta: 3e-09, 	Acceptance rate: 1.00, 	ESS: 993.34/1000, 	Best loss: 5757.208034,	Elapsed time: 17.22s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.2187 + 0.6372*x4 - 0.4662*x2 + 0.7768*x2^2*x5 + 0.2059*x2^3
# Iteration 72/1000, 	Beta: 3.2e-09, 	Acceptance rate: 1.00, 	ESS: 993.01/1000, 	Best loss: 5757.208034,	Elapsed time: 17.44s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 1.1658*x1*x2*x5 + 0.0066*x1*x2*x3 + 0.1377*x1^2*x3 + 0.0457*x3*x4*x5^3 - 0.2847*x1^2*x2*x5^2
# Iteration 73/1000, 	Beta: 3.4e-09, 	Acceptance rate: 1.00, 	ESS: 992.54/1000, 	Best loss: 5757.208034,	Elapsed time: 17.65s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.2187 + 0.6372*x4 - 0.3956*x2 + 0.2059*x2^2 + 0.7768*x2^2*x5
# Iteration 74/1000, 	Beta: 3.5e-09, 	Acceptance rate: 1.00, 	ESS: 993.24/1000, 	Best loss: 5757.208034,	Elapsed time: 17.88s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.2187 + 0.6372*x4 - 0.3956*x2 + 0.7768*x2*x5 + 0.2059*x2^2
# Iteration 75/1000, 	Beta: 3.7e-09, 	Acceptance rate: 1.00, 	ESS: 993.27/1000, 	Best loss: 5757.208034,	Elapsed time: 18.10s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.2187 + 0.6802*x4 - 0.3956*x2 + 0.7768*x2*x5 + 0.2059*x2^2
# Iteration 76/1000, 	Beta: 3.9e-09, 	Acceptance rate: 1.00, 	ESS: 993.25/1000, 	Best loss: 5757.208034,	Elapsed time: 18.30s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.2187 + 0.6902*x4 - 0.3956*x2 + 0.7768*x2*x5 + 0.2059*x2^2
# Iteration 77/1000, 	Beta: 4.1e-09, 	Acceptance rate: 1.00, 	ESS: 993.94/1000, 	Best loss: 5757.208034,	Elapsed time: 18.53s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 1.2270*x1*x2*x5 + 0.0066*x1*x2*x3 + 0.1377*x1^3 - 0.2847*x1*x2*x5^2 - 0.0094*x3*x4*x5^3
# Iteration 78/1000, 	Beta: 4.3e-09, 	Acceptance rate: 1.00, 	ESS: 993.75/1000, 	Best loss: 5757.208034,	Elapsed time: 18.78s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 1.2270*x1*x2*x5 + 0.0066*x1*x2*x3 + 0.0669*x1^3 - 0.2847*x1*x2*x5^2 - 0.0094*x3*x4*x5^3
# Iteration 79/1000, 	Beta: 4.5e-09, 	Acceptance rate: 1.00, 	ESS: 993.55/1000, 	Best loss: 5757.208034,	Elapsed time: 19.01s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2847*x1*x5^2 + 1.2270*x1*x2*x5 + 0.0066*x1*x2*x3 + 0.0669*x1^3 - 0.0094*x3*x4*x5^3
# Iteration 80/1000, 	Beta: 4.7e-09, 	Acceptance rate: 1.00, 	ESS: 993.67/1000, 	Best loss: 5757.208034,	Elapsed time: 19.27s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2847*x1*x5^2 + 1.2270*x1*x2*x5 + 0.0066*x1*x2*x3 + 0.0669*x1^3 - 0.0094*x3*x5^3
# Iteration 81/1000, 	Beta: 5e-09, 	Acceptance rate: 1.00, 	ESS: 993.49/1000, 	Best loss: 5757.208034,	Elapsed time: 19.52s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2847*x1*x5^2 + 1.2270*x1*x2*x5 - 0.0278*x1*x2*x3 + 0.0669*x1^3 - 0.0094*x3*x5^3
# Iteration 82/1000, 	Beta: 5.2e-09, 	Acceptance rate: 1.00, 	ESS: 993.09/1000, 	Best loss: 5757.208034,	Elapsed time: 19.78s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2847*x1*x5^2 + 1.2270*x1*x2*x5 - 0.0278*x1*x2*x3 + 0.0846*x1^3 - 0.0094*x3*x5^3
# Iteration 83/1000, 	Beta: 5.5e-09, 	Acceptance rate: 1.00, 	ESS: 993.00/1000, 	Best loss: 5757.208034,	Elapsed time: 20.02s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3191*x1*x5^2 + 1.2270*x1*x2*x5 - 0.0278*x1*x2*x3 + 0.0846*x1^3 - 0.0094*x3*x5^3
# Iteration 84/1000, 	Beta: 5.7e-09, 	Acceptance rate: 1.00, 	ESS: 992.56/1000, 	Best loss: 5757.208034,	Elapsed time: 20.29s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.0846*x1^2 - 0.3191*x1*x5^2 + 1.2270*x1*x2*x5 - 0.0278*x1*x2*x3 - 0.0094*x3*x5^3
# Iteration 85/1000, 	Beta: 6e-09, 	Acceptance rate: 1.00, 	ESS: 992.28/1000, 	Best loss: 5757.208034,	Elapsed time: 20.56s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.0846*x1^2 - 0.5098*x1*x5^2 + 1.2270*x1*x2*x5 - 0.0278*x1*x2*x3 - 0.0094*x3*x5^3
# Iteration 86/1000, 	Beta: 6.3e-09, 	Acceptance rate: 1.00, 	ESS: 992.64/1000, 	Best loss: 5757.208034,	Elapsed time: 20.84s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.0846*x1^2 - 0.5098*x1*x5^2 + 1.2591*x1*x2*x5 - 0.0278*x1*x2*x3 - 0.0094*x3*x5^3
# Iteration 87/1000, 	Beta: 6.6e-09, 	Acceptance rate: 1.00, 	ESS: 991.88/1000, 	Best loss: 5757.208034,	Elapsed time: 21.06s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.8397 + 0.0914*x2 + 0.0032*x2^3 + 0.7537*x1*x2*x5 - 0.0309*x1*x2*x3*x4^2
# Iteration 88/1000, 	Beta: 7e-09, 	Acceptance rate: 1.00, 	ESS: 991.68/1000, 	Best loss: 5757.208034,	Elapsed time: 21.29s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2074*x5 + 0.0515*x3 - 0.3922*x3^2 + 1.2145*x1*x2*x5 - 0.3504*x2*x3*x4*x5^2
# Iteration 89/1000, 	Beta: 7.3e-09, 	Acceptance rate: 1.00, 	ESS: 991.11/1000, 	Best loss: 5757.208034,	Elapsed time: 21.53s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2406*x5 - 0.5433*x1 - 0.2097*x3*x5^2 - 0.3813*x1*x2^3
# Iteration 90/1000, 	Beta: 7.7e-09, 	Acceptance rate: 1.00, 	ESS: 991.50/1000, 	Best loss: 5757.208034,	Elapsed time: 21.74s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2406*x5 - 0.5433*x1 - 0.2097*x3*x5^2 - 0.3813*x1*x2^3*x5
# Iteration 91/1000, 	Beta: 8.1e-09, 	Acceptance rate: 1.00, 	ESS: 991.28/1000, 	Best loss: 5757.208034,	Elapsed time: 22.01s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2406*x5 - 0.6647*x1 - 0.2097*x3*x5^2 - 0.3813*x1*x2^3*x5
# Iteration 92/1000, 	Beta: 8.5e-09, 	Acceptance rate: 1.00, 	ESS: 990.85/1000, 	Best loss: 5757.208034,	Elapsed time: 22.22s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2406*x5 - 0.6647*x1 - 0.3391*x3*x5^2 - 0.3813*x1*x2^3*x5
# Iteration 93/1000, 	Beta: 8.9e-09, 	Acceptance rate: 1.00, 	ESS: 991.08/1000, 	Best loss: 5757.208034,	Elapsed time: 22.47s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2406*x5 - 0.6647*x1*x5 - 0.3391*x3*x5^2 - 0.3813*x1*x2^3*x5
# Iteration 94/1000, 	Beta: 9.3e-09, 	Acceptance rate: 1.00, 	ESS: 990.52/1000, 	Best loss: 5757.208034,	Elapsed time: 22.70s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.6304*x2^2 - 0.2786*x1*x4 - 0.8055*x1*x2 - 0.1662*x4^2*x5 + 0.6698*x1*x2*x3^2
# Iteration 95/1000, 	Beta: 9.8e-09, 	Acceptance rate: 1.00, 	ESS: 990.27/1000, 	Best loss: 5757.208034,	Elapsed time: 22.94s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.6304*x2 - 0.2786*x1*x4 - 0.8055*x1*x2 - 0.1662*x4^2*x5 + 0.6698*x1*x2*x3^2
# Iteration 96/1000, 	Beta: 1e-08, 	Acceptance rate: 1.00, 	ESS: 989.87/1000, 	Best loss: 5757.208034,	Elapsed time: 23.16s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.6304*x2 - 0.2786*x1*x4 - 0.7248*x1*x2 - 0.1662*x4^2*x5 + 0.6698*x1*x2*x3^2
# Iteration 97/1000, 	Beta: 1.1e-08, 	Acceptance rate: 1.00, 	ESS: 989.61/1000, 	Best loss: 5757.208034,	Elapsed time: 23.38s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.6304*x2 - 0.2786*x1*x4 - 0.7248*x1*x2 - 0.1662*x4^2*x5 + 0.6482*x1*x2*x3^2
# Iteration 98/1000, 	Beta: 1.1e-08, 	Acceptance rate: 1.00, 	ESS: 989.77/1000, 	Best loss: 5757.208034,	Elapsed time: 23.61s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.1589*x5 - 0.6647*x1*x5 - 0.3813*x2^3 - 0.2822*x3*x4*x5^2
# Iteration 99/1000, 	Beta: 1.2e-08, 	Acceptance rate: 1.00, 	ESS: 989.32/1000, 	Best loss: 5757.208034,	Elapsed time: 23.81s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.1589*x5 - 0.6647*x1*x5 - 0.3813*x2^3 - 0.2573*x3*x4*x5^2
# Iteration 100/1000, 	Beta: 1.3e-08, 	Acceptance rate: 1.00, 	ESS: 988.86/1000, 	Best loss: 5757.208034,	Elapsed time: 24.05s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.1326 + 0.1173*x4 - 0.4255*x1 + 0.5662*x4*x5 + 0.8736*x2*x5
# Iteration 101/1000, 	Beta: 1.3e-08, 	Acceptance rate: 1.00, 	ESS: 990.06/1000, 	Best loss: 5757.208034,	Elapsed time: 24.25s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.1163 + 0.3908*x1*x2*x4 - 0.0855*x1*x2*x3 + 1.4756*x1*x3*x4*x5 - 0.3749*x1*x3*x4^2*x5
# Iteration 102/1000, 	Beta: 1.4e-08, 	Acceptance rate: 1.00, 	ESS: 989.54/1000, 	Best loss: 5757.208034,	Elapsed time: 24.51s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0554 + 0.2074*x3*x5 + 1.2236*x1*x5 - 0.4772*x3^2*x5 - 0.3504*x2*x3*x4*x5^2
# Iteration 103/1000, 	Beta: 1.4e-08, 	Acceptance rate: 1.00, 	ESS: 989.59/1000, 	Best loss: 5757.208034,	Elapsed time: 24.77s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0554 + 0.2074*x3*x5 + 1.2236*x1*x5 - 0.4772*x3^2*x5 - 0.3504*x2*x4*x5^2
# Iteration 104/1000, 	Beta: 1.5e-08, 	Acceptance rate: 1.00, 	ESS: 989.08/1000, 	Best loss: 5757.208034,	Elapsed time: 25.03s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0554 + 0.2074*x3*x5 - 0.4772*x3^2 + 1.2236*x1*x5 - 0.3504*x2*x4*x5^2
# Iteration 105/1000, 	Beta: 1.6e-08, 	Acceptance rate: 1.00, 	ESS: 988.33/1000, 	Best loss: 5757.208034,	Elapsed time: 25.29s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0554 + 0.3714*x3*x5 - 0.4772*x3^2 + 1.2236*x1*x5 - 0.3504*x2*x4*x5^2
# Iteration 106/1000, 	Beta: 1.7e-08, 	Acceptance rate: 1.00, 	ESS: 987.97/1000, 	Best loss: 5757.208034,	Elapsed time: 25.57s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2236 + 1.0544*x2 + 0.8954*x1 - 1.1842*x2*x4*x5 - 0.3715*x2*x3*x4*x5
# Iteration 107/1000, 	Beta: 1.8e-08, 	Acceptance rate: 1.00, 	ESS: 987.02/1000, 	Best loss: 5757.208034,	Elapsed time: 25.83s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0554 - 0.4772*x3 + 0.3714*x3*x5 + 1.2236*x1*x5 - 0.3504*x2*x4*x5^3
# Iteration 108/1000, 	Beta: 1.9e-08, 	Acceptance rate: 0.99, 	ESS: 986.51/1000, 	Best loss: 5757.208034,	Elapsed time: 26.09s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0975*x5 - 0.6647*x1*x5 - 0.3813*x2^3 - 0.4923*x1*x4*x5^2
# Iteration 109/1000, 	Beta: 1.9e-08, 	Acceptance rate: 0.99, 	ESS: 986.07/1000, 	Best loss: 5757.208034,	Elapsed time: 26.32s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0975*x5 - 0.6647*x1*x5 - 0.3813*x2^3*x4 - 0.4923*x1*x4*x5^2
# Iteration 110/1000, 	Beta: 2e-08, 	Acceptance rate: 1.00, 	ESS: 985.73/1000, 	Best loss: 5757.208034,	Elapsed time: 26.52s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2236 + 1.0544*x2 + 0.8954*x1 - 1.1842*x2*x4 - 0.1682*x2*x4^2*x5
# Iteration 111/1000, 	Beta: 2.1e-08, 	Acceptance rate: 0.99, 	ESS: 985.09/1000, 	Best loss: 5757.208034,	Elapsed time: 26.75s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2236 + 1.0544*x2 - 1.1842*x2*x4 + 0.8954*x1*x5 - 0.1682*x2*x4^2*x5
# Iteration 112/1000, 	Beta: 2.2e-08, 	Acceptance rate: 1.00, 	ESS: 984.94/1000, 	Best loss: 5757.208034,	Elapsed time: 26.95s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.6296*x1*x3*x5 - 0.6416*x1*x2*x4*x5 + 0.4829*x1^2*x4*x5 - 0.1738*x1*x2^2*x3*x5
# Iteration 113/1000, 	Beta: 2.4e-08, 	Acceptance rate: 1.00, 	ESS: 983.65/1000, 	Best loss: 5757.208034,	Elapsed time: 27.21s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.9723*x2 + 0.2708*x1 - 1.4122*x2*x4 + 0.4067*x2^2 - 0.5951*x2^2*x4
# Iteration 114/1000, 	Beta: 2.5e-08, 	Acceptance rate: 1.00, 	ESS: 983.69/1000, 	Best loss: 5757.208034,	Elapsed time: 27.49s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.9723*x2 + 0.2708*x1 - 1.4122*x2*x4 + 0.3664*x2^2 - 0.5951*x2^2*x4
# Iteration 115/1000, 	Beta: 2.6e-08, 	Acceptance rate: 0.99, 	ESS: 982.62/1000, 	Best loss: 5757.208034,	Elapsed time: 27.75s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.2708 + 0.9723*x2 - 1.4122*x2*x4 + 0.3664*x2^2 - 0.5951*x2^2*x4
# Iteration 116/1000, 	Beta: 2.7e-08, 	Acceptance rate: 1.00, 	ESS: 981.95/1000, 	Best loss: 5757.208034,	Elapsed time: 27.94s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3635 + 0.9723*x2 - 1.4122*x2*x4 + 0.3664*x2^2 - 0.5951*x2^2*x4
# Iteration 117/1000, 	Beta: 2.9e-08, 	Acceptance rate: 1.00, 	ESS: 982.82/1000, 	Best loss: 5757.208034,	Elapsed time: 28.12s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3635 + 1.0952*x2 - 1.4122*x2*x4 + 0.3664*x2^2 - 0.5951*x2^2*x4
# Iteration 118/1000, 	Beta: 3e-08, 	Acceptance rate: 1.00, 	ESS: 982.14/1000, 	Best loss: 5757.208034,	Elapsed time: 28.32s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3635 + 1.0952*x2 - 1.2396*x2*x4 + 0.3664*x2^2 - 0.5951*x2^2*x4
# Iteration 119/1000, 	Beta: 3.2e-08, 	Acceptance rate: 1.00, 	ESS: 981.44/1000, 	Best loss: 5757.208034,	Elapsed time: 28.53s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3635 + 1.0952*x2 - 1.3540*x2*x4 + 0.3664*x2^2 - 0.5951*x2^2*x4
# Iteration 120/1000, 	Beta: 3.3e-08, 	Acceptance rate: 1.00, 	ESS: 980.40/1000, 	Best loss: 5757.208034,	Elapsed time: 28.78s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3635 + 1.0952*x2 - 1.2793*x2*x4 + 0.3664*x2^2 - 0.5951*x2^2*x4
# Iteration 121/1000, 	Beta: 3.5e-08, 	Acceptance rate: 0.99, 	ESS: 979.78/1000, 	Best loss: 5757.208034,	Elapsed time: 29.01s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3807*x5 + 0.5223*x2*x4 - 0.7801*x2^2*x5 + 0.2022*x1*x5^2 + 0.5278*x2*x3*x5^2
# Iteration 122/1000, 	Beta: 3.7e-08, 	Acceptance rate: 0.99, 	ESS: 979.28/1000, 	Best loss: 5757.208034,	Elapsed time: 29.23s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3807*x5 + 0.5223*x2 - 0.7801*x2^2*x5 + 0.2022*x1*x5^2 + 0.5278*x2*x3*x5^2
# Iteration 123/1000, 	Beta: 3.8e-08, 	Acceptance rate: 1.00, 	ESS: 979.02/1000, 	Best loss: 5757.208034,	Elapsed time: 29.50s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3807*x5 + 0.5223*x2 - 0.7801*x2^2*x5 + 0.2911*x1*x5^2 + 0.5278*x2*x3*x5^2
# Iteration 124/1000, 	Beta: 4e-08, 	Acceptance rate: 1.00, 	ESS: 979.22/1000, 	Best loss: 5757.208034,	Elapsed time: 29.73s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3807*x5 + 0.5223*x2 - 0.7801*x2^2*x5 + 0.2911*x1*x5^2 + 0.5278*x1*x2*x3*x5^2
# Iteration 125/1000, 	Beta: 4.2e-08, 	Acceptance rate: 1.00, 	ESS: 978.27/1000, 	Best loss: 5757.208034,	Elapsed time: 29.95s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3807*x5 + 0.5223*x2 - 0.7801*x2^2*x5 + 0.1628*x1*x5^2 + 0.5278*x1*x2*x3*x5^2
# Iteration 126/1000, 	Beta: 4.5e-08, 	Acceptance rate: 1.00, 	ESS: 975.99/1000, 	Best loss: 5757.208034,	Elapsed time: 30.13s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3807*x5 + 0.5223*x2 - 0.7080*x2^2*x5 + 0.1628*x1*x5^2 + 0.5278*x1*x2*x3*x5^2
# Iteration 127/1000, 	Beta: 4.7e-08, 	Acceptance rate: 0.99, 	ESS: 975.02/1000, 	Best loss: 5757.208034,	Elapsed time: 30.40s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3246*x5 + 0.5223*x2 - 0.7080*x2^2*x5 + 0.1628*x1*x5^2 + 0.5278*x1*x2*x3*x5^2
# Iteration 128/1000, 	Beta: 4.9e-08, 	Acceptance rate: 1.00, 	ESS: 973.35/1000, 	Best loss: 5757.208034,	Elapsed time: 30.61s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3246*x5 + 0.5223*x2 - 0.7080*x2^2*x5 + 0.1628*x1*x5^2 + 0.5278*x1*x3*x5^2
# Iteration 129/1000, 	Beta: 5.2e-08, 	Acceptance rate: 1.00, 	ESS: 970.54/1000, 	Best loss: 5757.208034,	Elapsed time: 30.83s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.5223 + 0.3246*x5 - 0.7080*x2^2*x5 + 0.1628*x1*x5^2 + 0.5278*x1*x3*x5^2
# Iteration 130/1000, 	Beta: 5.4e-08, 	Acceptance rate: 0.99, 	ESS: 971.05/1000, 	Best loss: 5757.208034,	Elapsed time: 31.03s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.5045*x5 + 0.3605*x5^2 - 0.0738*x1*x4 + 0.8594*x1^2*x5 - 0.4069*x1*x5^3
# Iteration 131/1000, 	Beta: 5.7e-08, 	Acceptance rate: 0.99, 	ESS: 970.10/1000, 	Best loss: 5757.208034,	Elapsed time: 31.26s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.5045*x5 + 0.3605*x5^2 - 0.1035*x1*x4 + 0.8594*x1^2*x5 - 0.4069*x1*x5^3
# Iteration 132/1000, 	Beta: 6e-08, 	Acceptance rate: 1.00, 	ESS: 972.08/1000, 	Best loss: 5757.208034,	Elapsed time: 31.49s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.5045*x5 + 0.3605*x5^2 - 0.1035*x1*x4 + 0.9534*x1^2*x5 - 0.4069*x1*x5^3
# Iteration 133/1000, 	Beta: 6.3e-08, 	Acceptance rate: 1.00, 	ESS: 970.67/1000, 	Best loss: 5757.208034,	Elapsed time: 31.68s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.5223 + 0.3246*x5 - 0.8053*x2^2*x5 + 0.1628*x1*x5^2 + 0.4322*x1*x4*x5^2
# Iteration 134/1000, 	Beta: 6.6e-08, 	Acceptance rate: 1.00, 	ESS: 969.97/1000, 	Best loss: 5757.208034,	Elapsed time: 31.95s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.5223 + 0.3246*x5 - 0.8053*x2*x5 + 0.1628*x1*x5^2 + 0.4322*x1*x4*x5^2
# Iteration 135/1000, 	Beta: 6.9e-08, 	Acceptance rate: 1.00, 	ESS: 970.33/1000, 	Best loss: 5757.208034,	Elapsed time: 32.19s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.5223 - 0.8053*x2*x5 + 0.3246*x1*x5 + 0.1628*x1*x5^2 + 0.4322*x1*x4*x5^2
# Iteration 136/1000, 	Beta: 7.3e-08, 	Acceptance rate: 0.99, 	ESS: 968.14/1000, 	Best loss: 5757.208034,	Elapsed time: 32.45s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3528*x2^2 - 0.5882*x1*x4 - 0.1008*x1*x3 - 0.3257*x1*x2*x4*x5^2
# Iteration 137/1000, 	Beta: 7.6e-08, 	Acceptance rate: 0.99, 	ESS: 966.02/1000, 	Best loss: 5757.208034,	Elapsed time: 32.71s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3528*x2^2 - 0.5882*x1*x4 - 0.1501*x1*x3 - 0.3257*x1*x2*x4*x5^2
# Iteration 138/1000, 	Beta: 8e-08, 	Acceptance rate: 0.99, 	ESS: 965.45/1000, 	Best loss: 5757.208034,	Elapsed time: 32.94s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3362 - 1.1483*x1 - 0.7914*x1*x2 + 0.7149*x1*x2*x5^2 + 0.0016*x1^2*x5^3
# Iteration 139/1000, 	Beta: 8.4e-08, 	Acceptance rate: 0.99, 	ESS: 963.95/1000, 	Best loss: 5757.208034,	Elapsed time: 33.18s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3362 - 1.1483*x1 - 0.7914*x1*x2 + 0.6822*x1*x2*x5^2 + 0.0016*x1^2*x5^3
# Iteration 140/1000, 	Beta: 8.8e-08, 	Acceptance rate: 0.99, 	ESS: 963.23/1000, 	Best loss: 5757.208034,	Elapsed time: 33.45s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.6970*x1 - 0.9539*x3*x5 - 0.0880*x2*x3*x4^2 + 0.0010*x1*x3*x4^2 + 0.0510*x1^3*x2*x4
# Iteration 141/1000, 	Beta: 9.3e-08, 	Acceptance rate: 0.99, 	ESS: 963.66/1000, 	Best loss: 5757.208034,	Elapsed time: 33.64s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3362 - 1.1483*x1 - 0.5951*x1*x2*x5 + 0.6822*x1*x2*x5^2 + 0.0016*x1^2*x5^3
# Iteration 142/1000, 	Beta: 9.7e-08, 	Acceptance rate: 0.99, 	ESS: 963.39/1000, 	Best loss: 5757.208034,	Elapsed time: 33.87s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4313 + 0.8241*x2*x3 - 0.3306*x1^2 - 0.5916*x2*x3*x5^2 + 0.4519*x1^2*x2*x5
# Iteration 143/1000, 	Beta: 1e-07, 	Acceptance rate: 1.00, 	ESS: 961.81/1000, 	Best loss: 5757.208034,	Elapsed time: 34.06s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4313 - 0.3306*x1 + 0.8241*x2*x3 - 0.5916*x2*x3*x5^2 + 0.4519*x1^2*x2*x5
# Iteration 144/1000, 	Beta: 1.1e-07, 	Acceptance rate: 0.99, 	ESS: 961.02/1000, 	Best loss: 5757.208034,	Elapsed time: 34.30s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4313 - 0.3306*x1 + 0.9772*x2*x3 - 0.5916*x2*x3*x5^2 + 0.4519*x1^2*x2*x5
# Iteration 145/1000, 	Beta: 1.1e-07, 	Acceptance rate: 0.99, 	ESS: 958.90/1000, 	Best loss: 5757.208034,	Elapsed time: 34.55s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4313 - 0.3306*x1 + 0.9772*x2*x3 + 0.4519*x1^2*x5 - 0.5916*x2*x3*x5^2
# Iteration 146/1000, 	Beta: 1.2e-07, 	Acceptance rate: 0.99, 	ESS: 957.17/1000, 	Best loss: 5757.208034,	Elapsed time: 34.80s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4313 - 0.3306*x1 + 0.9772*x2*x3 + 0.4519*x1^2*x5 - 0.6081*x2*x3*x5^2
# Iteration 147/1000, 	Beta: 1.2e-07, 	Acceptance rate: 0.99, 	ESS: 956.44/1000, 	Best loss: 5757.208034,	Elapsed time: 35.00s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4313*x5 - 0.3306*x1 + 0.9772*x2*x3 + 0.4519*x1^2*x5 - 0.6081*x2*x3*x5^2
# Iteration 148/1000, 	Beta: 1.3e-07, 	Acceptance rate: 0.99, 	ESS: 954.80/1000, 	Best loss: 5757.208034,	Elapsed time: 35.23s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4313*x5 - 0.3306*x1 + 0.9301*x2*x3 + 0.4519*x1^2*x5 - 0.6081*x2*x3*x5^2
# Iteration 149/1000, 	Beta: 1.4e-07, 	Acceptance rate: 0.99, 	ESS: 952.87/1000, 	Best loss: 5757.208034,	Elapsed time: 35.44s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4313*x5 + 0.9301*x2*x3 - 0.3306*x1*x5 + 0.4519*x1^2*x5 - 0.6081*x2*x3*x5^2
# Iteration 150/1000, 	Beta: 1.4e-07, 	Acceptance rate: 0.99, 	ESS: 952.52/1000, 	Best loss: 5757.208034,	Elapsed time: 35.65s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4313*x5 + 0.9301*x2*x3 - 0.3164*x1*x5 + 0.4519*x1^2*x5 - 0.6081*x2*x3*x5^2
# Iteration 151/1000, 	Beta: 1.5e-07, 	Acceptance rate: 1.00, 	ESS: 952.25/1000, 	Best loss: 5757.208034,	Elapsed time: 35.88s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.5650*x3 - 0.1786*x1*x2^2*x3 - 0.1227*x1*x2^2*x4*x5 + 0.4262*x1^2*x2*x4*x5
# Iteration 152/1000, 	Beta: 1.6e-07, 	Acceptance rate: 0.99, 	ESS: 951.09/1000, 	Best loss: 5757.208034,	Elapsed time: 36.14s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4705*x3 - 0.1853*x5^2 - 0.4158*x1*x3 + 0.8628*x2^2*x5 + 0.0063*x1*x3*x4
# Iteration 153/1000, 	Beta: 1.7e-07, 	Acceptance rate: 0.99, 	ESS: 948.86/1000, 	Best loss: 5757.208034,	Elapsed time: 36.37s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4705*x3 - 0.1853*x5^2 + 0.0063*x3*x4 - 0.4158*x1*x3 + 0.8628*x2^2*x5
# Iteration 154/1000, 	Beta: 1.7e-07, 	Acceptance rate: 0.99, 	ESS: 946.88/1000, 	Best loss: 5757.208034,	Elapsed time: 36.60s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4705*x3 - 0.1853*x5^2 + 0.0063*x3*x4 - 0.4989*x1*x3 + 0.8628*x2^2*x5
# Iteration 155/1000, 	Beta: 1.8e-07, 	Acceptance rate: 0.99, 	ESS: 946.08/1000, 	Best loss: 5757.208034,	Elapsed time: 36.80s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4705*x3 - 0.1853*x5^2 + 0.0063*x3*x4 + 0.8628*x2^2 - 0.4989*x1*x3
# Iteration 156/1000, 	Beta: 1.9e-07, 	Acceptance rate: 1.00, 	ESS: 945.91/1000, 	Best loss: 5757.208034,	Elapsed time: 37.03s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4705*x3 - 0.1853*x5^2 + 0.0063*x3*x4 + 0.9396*x2^2 - 0.4989*x1*x3
# Iteration 157/1000, 	Beta: 2e-07, 	Acceptance rate: 0.99, 	ESS: 946.31/1000, 	Best loss: 5757.208034,	Elapsed time: 37.27s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.4705*x3 - 0.1853*x5^2 + 0.9396*x2^2 - 0.4989*x1*x3 + 0.0063*x2*x3*x4
# Iteration 158/1000, 	Beta: 2.1e-07, 	Acceptance rate: 0.99, 	ESS: 944.48/1000, 	Best loss: 5757.208034,	Elapsed time: 37.49s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3843*x1 + 0.0548*x4*x5 - 0.9127*x2^2*x4 - 0.0517*x1*x4*x5 + 0.2637*x1*x2*x3^2*x5
# Iteration 159/1000, 	Beta: 2.2e-07, 	Acceptance rate: 1.00, 	ESS: 944.15/1000, 	Best loss: 5757.208034,	Elapsed time: 37.74s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3843*x1 + 0.0548*x4*x5 - 0.9127*x2^2*x4 - 0.0517*x1*x4*x5 + 0.1950*x1*x2*x3^2*x5
# Iteration 160/1000, 	Beta: 2.3e-07, 	Acceptance rate: 0.98, 	ESS: 944.05/1000, 	Best loss: 5757.208034,	Elapsed time: 37.93s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.7075 + 1.0072*x5 - 0.8246*x1*x2 - 0.0411*x2^2*x3^2*x5 + 0.0557*x1*x2*x3^2*x4
# Iteration 161/1000, 	Beta: 2.5e-07, 	Acceptance rate: 0.99, 	ESS: 941.60/1000, 	Best loss: 5757.208034,	Elapsed time: 38.16s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.7075 + 1.0072*x5 - 0.8075*x1*x2 - 0.0411*x2^2*x3^2*x5 + 0.0557*x1*x2*x3^2*x4
# Iteration 162/1000, 	Beta: 2.6e-07, 	Acceptance rate: 0.99, 	ESS: 940.06/1000, 	Best loss: 5757.208034,	Elapsed time: 38.37s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.7075 + 1.0072*x5 - 0.8075*x1*x2 - 0.0411*x2^2*x3^2*x5 + 0.0929*x1*x2*x3^2*x4
# Iteration 163/1000, 	Beta: 2.7e-07, 	Acceptance rate: 0.99, 	ESS: 937.59/1000, 	Best loss: 5757.208034,	Elapsed time: 38.61s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.4807 + 0.0040*x3 + 1.4828*x2 - 0.1534*x5^2 - 0.2437*x1*x2^2*x4*x5
# Iteration 164/1000, 	Beta: 2.8e-07, 	Acceptance rate: 0.98, 	ESS: 935.46/1000, 	Best loss: 5757.208034,	Elapsed time: 38.79s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.4807 + 0.0040*x3 + 1.4181*x2 - 0.1534*x5^2 - 0.2437*x1*x2^2*x4*x5
# Iteration 165/1000, 	Beta: 3e-07, 	Acceptance rate: 0.99, 	ESS: 932.55/1000, 	Best loss: 5757.208034,	Elapsed time: 39.02s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.5801 + 1.0072*x5 - 0.8075*x1*x2 + 0.0427*x2^2*x3^2*x5 + 0.0929*x1*x2*x3^2*x4
# Iteration 166/1000, 	Beta: 3.1e-07, 	Acceptance rate: 0.99, 	ESS: 930.41/1000, 	Best loss: 5757.208034,	Elapsed time: 39.23s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.4828 + 0.0999*x3 + 1.4181*x2 - 0.1534*x5^2 - 0.2437*x1*x2^2*x4*x5
# Iteration 167/1000, 	Beta: 3.3e-07, 	Acceptance rate: 0.98, 	ESS: 929.20/1000, 	Best loss: 5757.208034,	Elapsed time: 39.45s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.4828 + 0.0999*x3 + 1.4181*x2 - 0.1534*x5^2 - 0.2437*x1*x2^2*x5
# Iteration 168/1000, 	Beta: 3.5e-07, 	Acceptance rate: 0.99, 	ESS: 925.63/1000, 	Best loss: 5757.208034,	Elapsed time: 39.65s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.6874*x5 + 0.5986*x2 + 1.1426*x1 + 0.1790*x1*x5 - 0.2027*x1*x2^2*x4^2
# Iteration 169/1000, 	Beta: 3.6e-07, 	Acceptance rate: 0.99, 	ESS: 923.80/1000, 	Best loss: 5757.208034,	Elapsed time: 39.88s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2170*x5 - 0.3179*x2 - 1.2025*x2*x3 + 0.5050*x1*x4 + 0.0078*x1^2*x5^2
# Iteration 170/1000, 	Beta: 3.8e-07, 	Acceptance rate: 0.98, 	ESS: 922.83/1000, 	Best loss: 5757.208034,	Elapsed time: 40.10s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6987 + 0.9822*x5 - 0.8075*x1 - 0.0714*x2^2*x3^2*x5 + 0.0929*x1*x2*x3^2*x4
# Iteration 171/1000, 	Beta: 4e-07, 	Acceptance rate: 0.99, 	ESS: 922.41/1000, 	Best loss: 5757.208034,	Elapsed time: 40.31s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.4828 + 0.0999*x3 + 1.4229*x2 - 0.1534*x5^2 - 0.2437*x1*x2^2
# Iteration 172/1000, 	Beta: 4.2e-07, 	Acceptance rate: 0.99, 	ESS: 918.74/1000, 	Best loss: 5757.208034,	Elapsed time: 40.50s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0908 + 1.1716*x3 + 1.0794*x1*x2 - 0.6253*x1*x2*x4 - 0.1437*x1^2*x2^2
# Iteration 173/1000, 	Beta: 4.4e-07, 	Acceptance rate: 0.99, 	ESS: 919.61/1000, 	Best loss: 5757.208034,	Elapsed time: 40.77s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0908 + 1.1716*x3 + 1.0794*x1*x2 - 0.5060*x1*x2*x4 - 0.1437*x1^2*x2^2
# Iteration 174/1000, 	Beta: 4.6e-07, 	Acceptance rate: 0.98, 	ESS: 917.27/1000, 	Best loss: 5757.208034,	Elapsed time: 40.98s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2170*x5 - 0.3568*x2 - 1.2025*x2*x3 + 0.3916*x1*x4 + 0.0078*x1^2*x5^2
# Iteration 175/1000, 	Beta: 4.9e-07, 	Acceptance rate: 0.99, 	ESS: 916.62/1000, 	Best loss: 5757.208034,	Elapsed time: 41.23s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.2170*x5 - 0.1721*x2 - 1.2025*x2*x3 + 0.3916*x1*x4 + 0.0078*x1^2*x5^2
# Iteration 176/1000, 	Beta: 5.1e-07, 	Acceptance rate: 0.98, 	ESS: 916.28/1000, 	Best loss: 5757.208034,	Elapsed time: 41.49s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3740*x1 - 0.6515*x5^2 - 0.1129*x2*x3*x4 - 0.0689*x1*x5^2
# Iteration 177/1000, 	Beta: 5.4e-07, 	Acceptance rate: 0.98, 	ESS: 913.05/1000, 	Best loss: 5757.208034,	Elapsed time: 41.72s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6515*x5 - 0.3740*x1 - 0.1129*x2*x3*x4 - 0.0689*x1*x5^2
# Iteration 178/1000, 	Beta: 5.6e-07, 	Acceptance rate: 0.98, 	ESS: 911.07/1000, 	Best loss: 5757.208034,	Elapsed time: 41.91s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6515*x5 - 0.3740*x1 - 0.1129*x2*x3*x4 - 0.0426*x1*x5^2
# Iteration 179/1000, 	Beta: 5.9e-07, 	Acceptance rate: 0.97, 	ESS: 907.99/1000, 	Best loss: 5757.208034,	Elapsed time: 42.16s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6515*x5 - 0.3740*x1 - 0.1129*x2*x3 - 0.0426*x1*x5^2
# Iteration 180/1000, 	Beta: 6.2e-07, 	Acceptance rate: 0.98, 	ESS: 904.08/1000, 	Best loss: 5757.208034,	Elapsed time: 42.38s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6515*x5 - 0.3740*x1 - 0.0426*x1*x5^2 - 0.1129*x1*x2*x3
# Iteration 181/1000, 	Beta: 6.5e-07, 	Acceptance rate: 0.98, 	ESS: 899.70/1000, 	Best loss: 5757.208034,	Elapsed time: 42.67s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6515*x5 - 0.3740*x1 - 0.1600*x1*x5^2 - 0.1129*x1*x2*x3
# Iteration 182/1000, 	Beta: 6.8e-07, 	Acceptance rate: 0.98, 	ESS: 899.14/1000, 	Best loss: 5757.208034,	Elapsed time: 42.88s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3740 - 0.6515*x5 - 0.1600*x1*x5^2 - 0.1129*x1*x2*x3
# Iteration 183/1000, 	Beta: 7.2e-07, 	Acceptance rate: 0.97, 	ESS: 896.77/1000, 	Best loss: 5757.208034,	Elapsed time: 43.17s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3740 - 0.6515*x5 - 0.2331*x1*x5^2 - 0.1129*x1*x2*x3
# Iteration 184/1000, 	Beta: 7.5e-07, 	Acceptance rate: 0.98, 	ESS: 891.55/1000, 	Best loss: 5757.208034,	Elapsed time: 43.38s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3740 - 0.6515*x5 - 0.1705*x1*x5^2 - 0.1129*x1*x2*x3
# Iteration 185/1000, 	Beta: 7.9e-07, 	Acceptance rate: 0.98, 	ESS: 887.88/1000, 	Best loss: 5757.208034,	Elapsed time: 43.59s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3740 - 0.6515*x5 - 0.0651*x1*x5^2 - 0.1129*x1*x2*x3
# Iteration 186/1000, 	Beta: 8.3e-07, 	Acceptance rate: 0.98, 	ESS: 885.15/1000, 	Best loss: 5757.208034,	Elapsed time: 43.81s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6515*x5 - 0.3740*x3 - 0.0651*x1*x5^2 - 0.1129*x1*x2*x3
# Iteration 187/1000, 	Beta: 8.7e-07, 	Acceptance rate: 0.98, 	ESS: 882.93/1000, 	Best loss: 5757.208034,	Elapsed time: 44.04s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6515*x5 - 0.3740*x3 - 0.0651*x1*x5^2 - 0.0490*x1*x2*x3
# Iteration 188/1000, 	Beta: 9.2e-07, 	Acceptance rate: 0.97, 	ESS: 880.52/1000, 	Best loss: 5757.208034,	Elapsed time: 44.26s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6515*x5 - 0.3740*x3 - 0.0490*x1*x2*x3 - 0.0651*x1*x3*x5^2
# Iteration 189/1000, 	Beta: 9.6e-07, 	Acceptance rate: 0.97, 	ESS: 876.94/1000, 	Best loss: 5757.208034,	Elapsed time: 44.49s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6515*x5 - 0.3740*x3 - 0.0133*x1*x2*x3 - 0.0651*x1*x3*x5^2
# Iteration 190/1000, 	Beta: 1e-06, 	Acceptance rate: 0.97, 	ESS: 873.29/1000, 	Best loss: 5757.208034,	Elapsed time: 44.73s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6515*x5 - 0.3740*x3 - 0.0133*x1*x2 - 0.0651*x1*x3*x5^2
# Iteration 191/1000, 	Beta: 1.1e-06, 	Acceptance rate: 0.98, 	ESS: 869.40/1000, 	Best loss: 5757.208034,	Elapsed time: 44.98s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.6515*x5 - 0.3740*x3 - 0.0133*x1*x2 - 0.0651*x1*x3^2*x5^2
# Iteration 192/1000, 	Beta: 1.1e-06, 	Acceptance rate: 0.98, 	ESS: 866.72/1000, 	Best loss: 5757.208034,	Elapsed time: 45.20s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.3740*x3 - 0.6515*x4*x5 - 0.0133*x1*x2 - 0.0651*x1*x3^2*x5^2
# Iteration 193/1000, 	Beta: 1.2e-06, 	Acceptance rate: 0.97, 	ESS: 862.58/1000, 	Best loss: 5757.208034,	Elapsed time: 45.42s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0102*x4 + 0.6341*x3 + 0.5947*x2 + 0.3549*x1 - 0.5957*x1^2*x2
# Iteration 194/1000, 	Beta: 1.2e-06, 	Acceptance rate: 0.97, 	ESS: 858.94/1000, 	Best loss: 5757.208034,	Elapsed time: 45.66s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0102*x4 + 0.6341*x3 + 0.6181*x2 + 0.3549*x1 - 0.5957*x1^2*x2
# Iteration 195/1000, 	Beta: 1.3e-06, 	Acceptance rate: 0.97, 	ESS: 855.71/1000, 	Best loss: 5757.208034,	Elapsed time: 45.95s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.0102*x4 + 0.6341*x3 + 0.7655*x2 + 0.3549*x1 - 0.5957*x1^2*x2
# Iteration 196/1000, 	Beta: 1.4e-06, 	Acceptance rate: 0.97, 	ESS: 849.57/1000, 	Best loss: 5757.208034,	Elapsed time: 46.14s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : 0.3444*x5 + 0.1203*x4 - 0.7777*x2 + 0.3255*x1 - 0.8539*x1^2*x5
# ...
# Iteration 938/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 779.70/1000, 	Best loss: 309.751844,	Elapsed time: 226.57s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9494*x2 + 1.0326*x2*x4 - 0.7180*x1*x5 - 0.9975*x1*x3 + 0.4971*x2*x4*x5^2
# Iteration 939/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 748.46/1000, 	Best loss: 309.751844,	Elapsed time: 226.84s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9494*x2 + 1.0326*x2*x4 - 0.7180*x1*x5 - 0.9975*x1*x3 + 0.4971*x2*x4*x5^2
# Iteration 940/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 570.98/1000, 	Best loss: 309.751844,	Elapsed time: 227.09s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9494*x2 + 1.0326*x2*x4 - 0.7180*x1*x5 - 0.9975*x1*x3 + 0.4971*x2*x4*x5^2
# ESS = 229.72 : resampling needed
# Iteration 941/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 1000.00/1000, 	Best loss: 309.751844,	Elapsed time: 227.38s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9773*x2 + 0.9428*x2*x4 - 0.6943*x1*x5 - 0.9234*x1*x3 + 0.5074*x2*x4*x5^2
# Iteration 942/1000, 	Beta: 0.0097, 	Acceptance rate: 0.39, 	ESS: 900.22/1000, 	Best loss: 309.751844,	Elapsed time: 227.65s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9773*x2 + 0.9428*x2*x4 - 0.6943*x1*x5 - 0.9234*x1*x3 + 0.5074*x2*x4*x5^2
# Iteration 943/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 792.84/1000, 	Best loss: 309.751844,	Elapsed time: 227.93s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9773*x2 + 0.9428*x2*x4 - 0.6943*x1*x5 - 0.9234*x1*x3 + 0.5074*x2*x4*x5^2
# Iteration 944/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 659.82/1000, 	Best loss: 309.751844,	Elapsed time: 228.20s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9773*x2 + 0.9428*x2*x4 - 0.6943*x1*x5 - 0.9234*x1*x3 + 0.5074*x2*x4*x5^2
# Iteration 945/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 611.18/1000, 	Best loss: 309.751844,	Elapsed time: 228.48s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9773*x2 + 0.9428*x2*x4 - 0.6921*x1*x5 - 0.9234*x1*x3 + 0.5074*x2*x4*x5^2
# ESS = 282.16 : resampling needed
# Iteration 946/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 1000.00/1000, 	Best loss: 309.751844,	Elapsed time: 228.72s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0499*x2 + 0.9827*x2*x4 - 0.6043*x1*x5 - 0.9580*x1*x3 + 0.4817*x2*x4*x5^2
# Iteration 947/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 906.70/1000, 	Best loss: 309.751844,	Elapsed time: 228.98s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0499*x2 + 1.0120*x2*x4 - 0.6043*x1*x5 - 0.9580*x1*x3 + 0.4817*x2*x4*x5^2
# Iteration 948/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 830.48/1000, 	Best loss: 291.210225,	Elapsed time: 229.21s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9743*x2 + 0.9881*x2*x4 - 0.6691*x1*x5 - 0.9803*x1*x3 + 0.4485*x2*x4*x5^2
# Iteration 949/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 691.92/1000, 	Best loss: 291.210225,	Elapsed time: 229.46s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9743*x2 + 0.9881*x2*x4 - 0.6691*x1*x5 - 0.9803*x1*x3 + 0.4485*x2*x4*x5^2
# Iteration 950/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 660.83/1000, 	Best loss: 291.210225,	Elapsed time: 229.74s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9743*x2 + 0.9881*x2*x4 - 0.6691*x1*x5 - 0.9803*x1*x3 + 0.4485*x2*x4*x5^2
# Iteration 951/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 597.28/1000, 	Best loss: 291.210225,	Elapsed time: 229.99s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9743*x2 + 0.9881*x2*x4 - 0.6691*x1*x5 - 0.9803*x1*x3 + 0.4485*x2*x4*x5^2
# Iteration 952/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 545.80/1000, 	Best loss: 287.357654,	Elapsed time: 230.25s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0244*x2 + 1.0446*x2*x4 - 0.6691*x1*x5 - 0.9803*x1*x3 + 0.4684*x2*x4*x5^2
# ESS = 416.50 : resampling needed
# Iteration 953/1000, 	Beta: 0.0097, 	Acceptance rate: 0.32, 	ESS: 1000.00/1000, 	Best loss: 285.181466,	Elapsed time: 230.48s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9954*x2 + 1.0588*x2*x4 - 0.7676*x1*x5 - 1.0493*x1*x3 + 0.4600*x2*x4*x5^2
# Iteration 954/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 886.72/1000, 	Best loss: 285.181466,	Elapsed time: 230.74s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9954*x2 + 1.0588*x2*x4 - 0.7676*x1*x5 - 1.0493*x1*x3 + 0.4600*x2*x4*x5^2
# Iteration 955/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 813.53/1000, 	Best loss: 264.815065,	Elapsed time: 231.01s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9946*x2 + 1.0588*x2*x4 - 0.7676*x1*x5 - 1.0493*x1*x3 + 0.5154*x2*x4*x5^2
# Iteration 956/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 713.04/1000, 	Best loss: 264.815065,	Elapsed time: 231.26s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -0.9946*x2 + 1.0588*x2*x4 - 0.7676*x1*x5 - 1.0493*x1*x3 + 0.5154*x2*x4*x5^2
# Iteration 957/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 688.42/1000, 	Best loss: 264.815065,	Elapsed time: 231.54s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0456*x2 + 1.0588*x2*x4 - 0.7398*x1*x5 - 1.0493*x1*x3 + 0.4600*x2*x4*x5^2
# Iteration 958/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 641.99/1000, 	Best loss: 264.815065,	Elapsed time: 231.76s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0456*x2 + 1.0588*x2*x4 - 0.7398*x1*x5 - 1.0493*x1*x3 + 0.4600*x2*x4*x5^2
# Iteration 959/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 655.22/1000, 	Best loss: 264.815065,	Elapsed time: 232.04s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0456*x2 + 1.0588*x2*x4 - 0.7398*x1*x5 - 1.0493*x1*x3 + 0.4600*x2*x4*x5^2
# Iteration 960/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 559.03/1000, 	Best loss: 264.815065,	Elapsed time: 232.29s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0456*x2 + 1.0588*x2*x4 - 0.7398*x1*x5 - 1.0493*x1*x3 + 0.4600*x2*x4*x5^2
# ESS = 496.93 : resampling needed
# Iteration 961/1000, 	Beta: 0.0097, 	Acceptance rate: 0.37, 	ESS: 1000.00/1000, 	Best loss: 264.815065,	Elapsed time: 232.54s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0456*x2 + 1.0588*x2*x4 - 0.7398*x1*x5 - 1.0493*x1*x3 + 0.4600*x2*x4*x5^2
# Iteration 962/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 786.02/1000, 	Best loss: 264.815065,	Elapsed time: 232.78s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0245*x2 + 1.0133*x2*x4 - 0.7117*x1*x5 - 0.9826*x1*x3 + 0.4643*x2*x4*x5^2
# ESS = 464.76 : resampling needed
# Iteration 963/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 1000.00/1000, 	Best loss: 264.815065,	Elapsed time: 233.04s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0324*x2 + 1.0656*x2*x4 - 0.7676*x1*x5 - 1.0493*x1*x3 + 0.4600*x2*x4*x5^2
# Iteration 964/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 883.34/1000, 	Best loss: 264.815065,	Elapsed time: 233.30s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0245*x2 + 1.0133*x2*x4 - 0.7117*x1*x5 - 0.9826*x1*x3 + 0.4643*x2*x4*x5^2
# Iteration 965/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 565.94/1000, 	Best loss: 248.744456,	Elapsed time: 233.58s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7676*x1*x5 - 1.0844*x1*x3 + 0.5256*x2*x4*x5^2
# ESS = 195.67 : resampling needed
# Iteration 966/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 1000.00/1000, 	Best loss: 248.744456,	Elapsed time: 233.79s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7676*x1*x5 - 1.0844*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 967/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 749.78/1000, 	Best loss: 248.744456,	Elapsed time: 234.04s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7676*x1*x5 - 1.0844*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 968/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 753.05/1000, 	Best loss: 248.744456,	Elapsed time: 234.28s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7676*x1*x5 - 1.0844*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 969/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 681.00/1000, 	Best loss: 248.744456,	Elapsed time: 234.51s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7676*x1*x5 - 1.0844*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 970/1000, 	Beta: 0.0097, 	Acceptance rate: 0.37, 	ESS: 627.71/1000, 	Best loss: 248.744456,	Elapsed time: 234.79s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7676*x1*x5 - 1.0380*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 971/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 628.10/1000, 	Best loss: 248.744456,	Elapsed time: 235.01s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7057*x1*x5 - 1.0380*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 972/1000, 	Beta: 0.0097, 	Acceptance rate: 0.37, 	ESS: 592.83/1000, 	Best loss: 248.744456,	Elapsed time: 235.29s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7057*x1*x5 - 1.0380*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 973/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 551.92/1000, 	Best loss: 246.461534,	Elapsed time: 235.54s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7057*x1*x5 - 1.0580*x1*x3 + 0.5256*x2*x4*x5^2
# ESS = 489.08 : resampling needed
# Iteration 974/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 1000.00/1000, 	Best loss: 246.461534,	Elapsed time: 235.81s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7057*x1*x5 - 1.0580*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 975/1000, 	Beta: 0.0097, 	Acceptance rate: 0.33, 	ESS: 915.54/1000, 	Best loss: 246.461534,	Elapsed time: 236.04s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7057*x1*x5 - 1.0580*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 976/1000, 	Beta: 0.0097, 	Acceptance rate: 0.39, 	ESS: 837.79/1000, 	Best loss: 246.461534,	Elapsed time: 236.30s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7057*x1*x5 - 1.0580*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 977/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 760.37/1000, 	Best loss: 246.461534,	Elapsed time: 236.49s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7057*x1*x5 - 1.0580*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 978/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 713.93/1000, 	Best loss: 246.461534,	Elapsed time: 236.76s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7057*x1*x5 - 1.0580*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 979/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 667.15/1000, 	Best loss: 246.461534,	Elapsed time: 237.01s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7057*x1*x5 - 1.0580*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 980/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 645.04/1000, 	Best loss: 246.461534,	Elapsed time: 237.27s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7057*x1*x5 - 1.0580*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 981/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 637.77/1000, 	Best loss: 246.461534,	Elapsed time: 237.56s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0898*x2 + 1.0588*x2*x4 - 0.7057*x1*x5 - 1.0580*x1*x3 + 0.5256*x2*x4*x5^2
# Iteration 982/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 575.24/1000, 	Best loss: 246.461534,	Elapsed time: 237.78s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0163*x2 + 1.0588*x2*x4 - 0.7852*x1*x5 - 1.1026*x1*x3 + 0.5676*x2*x4*x5^2
# ESS = 355.60 : resampling needed
# Iteration 983/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 1000.00/1000, 	Best loss: 246.461534,	Elapsed time: 238.04s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0163*x2 + 1.0588*x2*x4 - 0.7852*x1*x5 - 1.1026*x1*x3 + 0.5676*x2*x4*x5^2
# Iteration 984/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 735.68/1000, 	Best loss: 246.461534,	Elapsed time: 238.34s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0163*x2 + 1.0588*x2*x4 - 0.7852*x1*x5 - 1.1026*x1*x3 + 0.5676*x2*x4*x5^2
# Iteration 985/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 699.78/1000, 	Best loss: 246.461534,	Elapsed time: 238.60s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0163*x2 + 1.0588*x2*x4 - 0.7852*x1*x5 - 1.1026*x1*x3 + 0.5676*x2*x4*x5^2
# Iteration 986/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 665.65/1000, 	Best loss: 246.461534,	Elapsed time: 238.82s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0163*x2 + 1.0588*x2*x4 - 0.7852*x1*x5 - 1.1026*x1*x3 + 0.5676*x2*x4*x5^2
# Iteration 987/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 534.66/1000, 	Best loss: 246.461534,	Elapsed time: 239.05s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0163*x2 + 1.0588*x2*x4 - 0.7852*x1*x5 - 1.1026*x1*x3 + 0.5676*x2*x4*x5^2
# Iteration 988/1000, 	Beta: 0.0097, 	Acceptance rate: 0.33, 	ESS: 592.91/1000, 	Best loss: 246.461534,	Elapsed time: 239.37s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0163*x2 + 1.0588*x2*x4 - 0.7852*x1*x5 - 1.1026*x1*x3 + 0.5676*x2*x4*x5^2
# Iteration 989/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 568.96/1000, 	Best loss: 246.461534,	Elapsed time: 239.63s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0163*x2 + 1.0588*x2*x4 - 0.7852*x1*x5 - 1.1026*x1*x3 + 0.5676*x2*x4*x5^2
# Iteration 990/1000, 	Beta: 0.0097, 	Acceptance rate: 0.38, 	ESS: 577.60/1000, 	Best loss: 246.461534,	Elapsed time: 239.91s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0163*x2 + 1.0588*x2*x4 - 0.7852*x1*x5 - 1.0587*x1*x3 + 0.5676*x2*x4*x5^2
# Iteration 991/1000, 	Beta: 0.0097, 	Acceptance rate: 0.32, 	ESS: 545.50/1000, 	Best loss: 246.461534,	Elapsed time: 240.14s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0163*x2 + 1.0588*x2*x4 - 0.7852*x1*x5 - 1.0587*x1*x3 + 0.5676*x2*x4*x5^2
# ESS = 424.51 : resampling needed
# Iteration 992/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 1000.00/1000, 	Best loss: 246.461534,	Elapsed time: 240.41s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.1089*x2 + 1.0522*x2*x4 - 0.7327*x1*x5 - 1.0493*x1*x3 + 0.5618*x2*x4*x5^2
# Iteration 993/1000, 	Beta: 0.0097, 	Acceptance rate: 0.31, 	ESS: 936.80/1000, 	Best loss: 246.461534,	Elapsed time: 240.64s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.1089*x2 + 1.0522*x2*x4 - 0.7327*x1*x5 - 1.0493*x1*x3 + 0.5618*x2*x4*x5^2
# Iteration 994/1000, 	Beta: 0.0097, 	Acceptance rate: 0.33, 	ESS: 880.25/1000, 	Best loss: 246.461534,	Elapsed time: 240.89s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0163*x2 + 1.0588*x2*x4 - 0.8226*x1*x5 - 1.0587*x1*x3 + 0.5676*x2*x4*x5^2
# Iteration 995/1000, 	Beta: 0.0097, 	Acceptance rate: 0.32, 	ESS: 737.96/1000, 	Best loss: 246.461534,	Elapsed time: 241.16s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0479*x2 + 1.0303*x2*x4 - 0.7008*x1*x5 - 1.0192*x1*x3 + 0.4939*x2*x4*x5^2
# Iteration 996/1000, 	Beta: 0.0097, 	Acceptance rate: 0.36, 	ESS: 705.40/1000, 	Best loss: 246.461534,	Elapsed time: 241.41s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0479*x2 + 1.0303*x2*x4 - 0.7008*x1*x5 - 1.0192*x1*x3 + 0.4939*x2*x4*x5^2
# Iteration 997/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 564.81/1000, 	Best loss: 246.461534,	Elapsed time: 241.64s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0479*x2 + 1.0303*x2*x4 - 0.7008*x1*x5 - 1.0192*x1*x3 + 0.4939*x2*x4*x5^2
# Iteration 998/1000, 	Beta: 0.0097, 	Acceptance rate: 0.34, 	ESS: 537.86/1000, 	Best loss: 242.079954,	Elapsed time: 241.88s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0598*x2 + 1.1420*x2*x4 - 0.8359*x1*x5 - 1.1636*x1*x3 + 0.5709*x2*x4*x5^2
# Iteration 999/1000, 	Beta: 0.0097, 	Acceptance rate: 0.35, 	ESS: 525.44/1000, 	Best loss: 242.079954,	Elapsed time: 242.17s, 	Prob (0.5, 0.25, 0.25, 0.0, 0.0), 	Best pol : -1.0518*x2 + 1.1420*x2*x4 - 0.8359*x1*x5 - 1.1636*x1*x3 + 0.5709*x2*x4*x5^2
#
# Total execution time: 242.17s
# Best loss: 242.079954
# Number of monomials in best solution: 5

# %%
best_coeffs = all_out[0]
bc_trunc = sampler.apply_coefficient_threshold(best_coeffs)
print(sampler.evaluate_polynomial_batch(np.array([bc_trunc])))

res, loss = sampler.local_search(best_coeffs,n_steps=1000,use_reg=False)
print(loss)
# Out:
# [34.00362319]
# [0.00285273]

# %%
sampler.polynomial_to_string(res)
sampler.min_coeff_threshold = 1e-3
res_trunc = sampler.apply_coefficient_threshold(res)
nonzero_indices = np.nonzero(res_trunc)
coeff_min = np.min(abs(res_trunc[nonzero_indices]))

print(sampler.polynomial_to_string(res_trunc/coeff_min))
# Out:
# -1.9972*x2 + 1.9969*x2*x4 - 1.4140*x1*x5 - 1.9979*x1*x3 + x2*x4*x5^2
